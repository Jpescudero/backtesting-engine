# %%
a = 2+3

# %%
a
# Out:
# 5

# %%
import os, sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
SRC_PATH = os.path.join(PROJECT_ROOT, "src")

print("PROJECT_ROOT:", PROJECT_ROOT)
print("SRC_PATH:", SRC_PATH)
print("Contenido de PROJECT_ROOT:", os.listdir(PROJECT_ROOT))
print("Contenido de SRC_PATH:", os.listdir(SRC_PATH))
# Out:
# PROJECT_ROOT: C:\Users\JorgeP\OneDrive\Bolsa\Scripts\10. Backtesting
# SRC_PATH: C:\Users\JorgeP\OneDrive\Bolsa\Scripts\10. Backtesting\src
# Contenido de PROJECT_ROOT: ['.git', '.gitignore', '.idea', 'backtesting_project_structure.txt', 'data', 'main.py', 'notebooks', 'README.md', 'reports', 'run_settings.example.txt', 'src', '__pycache__']
# Contenido de SRC_PATH: ['analytics', 'config', 'data', 'engine', 'pipeline', 'strategies', 'utils', 'visualization']

# %%
import os

print(os.listdir(SRC_PATH))
# Out:
# ['analytics', 'config', 'data', 'engine', 'pipeline', 'strategies', 'utils', 'visualization']

# %%
from engine import backtest_engine  # ejemplo
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from engine import backtest_engine  # ejemplo
#
# ImportError: cannot import name 'backtest_engine' from 'engine' (unknown location)
